# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./world-development-indicators/Indicators.csv')
data.shape
data.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
indicators = data.IndicatorName.unique()

# %%
indicators.size
# Out:
# 1344

# %%
def get_corr(df, country):

    df.dropna()

    country_mask = df["CountryName"] == country
    year_mask1 = df["Year"] > 1992
    year_mask2 = df["Year"] < 2010
    indicator_mask1 = df["IndicatorName"] == "Female legislators, senior officials and managers (% of total)"
    indicator_mask2 = df["IndicatorName"] == "GDP per capita (constant LCU)"

    country_mask.head(50)
    # year_mask1.size
    # year_mask2.size
    df_filtered = df[year_mask1 & year_mask2 & country_mask & (indicator_mask1 | indicator_mask2)]
    piv = df_filtered.pivot(index='Year', columns='IndicatorName', values='Value')
    piv.head(50)
    piv.corr()
    return piv

# %%
get_corr(data, "Italy").corr()
# Out:
# IndicatorName                                       Female legislators, senior officials and managers (% of total)  \
# IndicatorName
# Female legislators, senior officials and manage...                                           1.000000
# GDP per capita (constant LCU)                                                                0.719053
#
# IndicatorName                                       GDP per capita (constant LCU)
# IndicatorName
# Female legislators, senior officials and manage...                       0.719053
# GDP per capita (constant LCU)                                            1.000000

# %%
countries = data["CountryName"].unique()
for country in countries:
    print(country)
# Out:
# Arab World
# Caribbean small states
# Central Europe and the Baltics
# East Asia & Pacific (all income levels)
# East Asia & Pacific (developing only)
# Euro area
# Europe & Central Asia (all income levels)
# Europe & Central Asia (developing only)
# European Union
# Fragile and conflict affected situations
# Heavily indebted poor countries (HIPC)
# High income
# High income: nonOECD
# High income: OECD
# Latin America & Caribbean (all income levels)
# Latin America & Caribbean (developing only)
# Least developed countries: UN classification
# Low & middle income
# Low income
# Lower middle income
# Middle East & North Africa (all income levels)
# Middle East & North Africa (developing only)
# Middle income
# North America
# OECD members
# Other small states
# Pacific island small states
# Small states
# South Asia
# Sub-Saharan Africa (all income levels)
# Sub-Saharan Africa (developing only)
# Upper middle income
# World
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas, The
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cabo Verde
# Cambodia
# Cameroon
# Canada
# Cayman Islands
# Central African Republic
# Chad
# Channel Islands
# Chile
# China
# Colombia
# Comoros
# Congo, Dem. Rep.
# Congo, Rep.
# Costa Rica
# Cote d'Ivoire
# Croatia
# Cuba
# Curacao
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt, Arab Rep.
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faeroe Islands
# Fiji
# Finland
# France
# French Polynesia
# Gabon
# Gambia, The
# Georgia
# Germany
# Ghana
# Greece
# Greenland
# Grenada
# Guam
# Guatemala
# Guinea
# Guinea-Bissau
# Guyana
# Haiti
# Honduras
# Hong Kong SAR, China
# Hungary
# Iceland
# India
# Indonesia
# Iran, Islamic Rep.
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kiribati
# Korea, Dem. Rep.
# Korea, Rep.
# Kosovo
# Kuwait
# Kyrgyz Republic
# Lao PDR
# Latvia
# Lebanon
# Lesotho
# Liberia
# Libya
# Liechtenstein
# Lithuania
# Luxembourg
# Macao SAR, China
# Macedonia, FYR
# Madagascar
# Malawi
# Malaysia
# Maldives
# Mali
# Malta
# Marshall Islands
# Mauritania
# Mauritius
# Mexico
# Micronesia, Fed. Sts.
# Moldova
# Monaco
# Mongolia
# Montenegro
# Morocco
# Mozambique
# Myanmar
# Namibia
# Nepal
# Netherlands
# New Caledonia
# New Zealand
# Nicaragua
# Niger
# Nigeria
# Northern Mariana Islands
# Norway
# Oman
# Pakistan
# Palau
# Panama
# Papua New Guinea
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Romania
# Russian Federation
# Rwanda
# Samoa
# San Marino
# Sao Tome and Principe
# Saudi Arabia
# Senegal
# Serbia
# Seychelles
# Sierra Leone
# Singapore
# Sint Maarten (Dutch part)
# Slovak Republic
# Slovenia
# Solomon Islands
# Somalia
# South Africa
# South Sudan
# Spain
# Sri Lanka
# St. Kitts and Nevis
# St. Lucia
# St. Martin (French part)
# St. Vincent and the Grenadines
# Sudan
# Suriname
# Swaziland
# Sweden
# Switzerland
# Syrian Arab Republic
# Tajikistan
# Tanzania
# Thailand
# Timor-Leste
# Togo
# Tonga
# Trinidad and Tobago
# Tunisia
# Turkey
# Turkmenistan
# Turks and Caicos Islands
# Tuvalu
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States
# Uruguay
# Uzbekistan
# Vanuatu
# Venezuela, RB
# Vietnam
# Virgin Islands (U.S.)
# West Bank and Gaza
# Yemen, Rep.
# Zambia
# Zimbabwe

# %%
germany_data = data[data["CountryName"] == "Germany"]

# %%
germany_data.head()
# Out:
#       CountryName CountryCode  \
# 10004     Germany         DEU
# 10005     Germany         DEU
# 10006     Germany         DEU
# 10007     Germany         DEU
# 10008     Germany         DEU
#
#                                            IndicatorName      IndicatorCode  \
# 10004  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 10005  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 10006  Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 10007  Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 10008  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
#
#        Year      Value
# 10004  1960  37.979800
# 10005  1960  49.140380
# 10006  1960  17.167975
# 10007  1960  31.972405
# 10008  1960   0.727910

# %%
# data["CountryName_Year"] = data["CountryName"] + "_" + data["Year"].to_string()
# data.set_index()
# data.head()
# germany_reduced = germany_data[germany_data["IndicatorName"] == "Female legislators, senior officials and managers (% of total)"]
# germany_reduced = germany_reduced[germany_reduced["IndicatorName"] == ""]
pivot = pd.pivot_table(data, index=['Year', 'CountryName'], columns='IndicatorName', values='Value', aggfunc='mean')
pivot = pivot[["Birth rate, crude (per 1,000 people)", "Urban population (% of total)"]]

# %%
pivot.dropna()
pivot.head(-10)
pivot.corr()
# Out:
# IndicatorName                         Birth rate, crude (per 1,000 people)  \
# IndicatorName
# Birth rate, crude (per 1,000 people)                              1.000000
# Urban population (% of total)                                    -0.682624
#
# IndicatorName                         Urban population (% of total)
# IndicatorName
# Birth rate, crude (per 1,000 people)                      -0.682624
# Urban population (% of total)                              1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.xaxis.grid(True)
axis.set_title(indicatorsFilter[0],fontsize=10)
axis.set_xlabel(filteredData1['CountryName'].iloc[0],fontsize=10)
axis.set_ylabel(filteredData2['CountryName'].iloc[0],fontsize=10)

X = filteredData1['Value']
Y = filteredData2['Value']

axis.scatter(X, Y)

# %%
pivot.to_excel("pivot.xlsx")

# %%
pivot.corr()
# Out:
# IndicatorName                                       2005 PPP conversion factor, GDP (LCU per international $)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       2005 PPP conversion factor, private consumption (LCU per international $)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       Access to electricity (% of population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                      NaN
# 2005 PPP conversion factor, private consumption...                                      NaN
# Access to electricity (% of population)                                                 NaN
# Access to electricity, rural (% of rural popula...                                      NaN
# Access to electricity, urban (% of urban popula...                                      NaN
# ...                                                                                     ...
# Wage and salaried workers, female (% of females...                                      NaN
# Wage and salaried workers, total (% of total em...                                      NaN
# Wage and salary workers, male (% of males emplo...                                      NaN
# Water productivity, total (constant 2005 US$ GD...                                      NaN
# Wholesale price index (2010 = 100)                                                      NaN
#
# IndicatorName                                       Access to electricity, rural (% of rural population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       Access to electricity, urban (% of urban population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       Access to non-solid fuel (% of population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                         NaN
# 2005 PPP conversion factor, private consumption...                                         NaN
# Access to electricity (% of population)                                                    NaN
# Access to electricity, rural (% of rural popula...                                         NaN
# Access to electricity, urban (% of urban popula...                                         NaN
# ...                                                                                        ...
# Wage and salaried workers, female (% of females...                                         NaN
# Wage and salaried workers, total (% of total em...                                         NaN
# Wage and salary workers, male (% of males emplo...                                         NaN
# Water productivity, total (constant 2005 US$ GD...                                         NaN
# Wholesale price index (2010 = 100)                                                         NaN
#
# IndicatorName                                       Access to non-solid fuel, rural (% of rural population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       Access to non-solid fuel, urban (% of urban population)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                                NaN
# Wage and salaried workers, total (% of total em...                                                NaN
# Wage and salary workers, male (% of males emplo...                                                NaN
# Water productivity, total (constant 2005 US$ GD...                                                NaN
# Wholesale price index (2010 = 100)                                                                NaN
#
# IndicatorName                                       Adjusted net enrolment rate, primary, both sexes (%)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                          -0.008454
# Wage and salaried workers, total (% of total em...                                           0.003914
# Wage and salary workers, male (% of males emplo...                                          -0.039696
# Water productivity, total (constant 2005 US$ GD...                                           0.917444
# Wholesale price index (2010 = 100)                                                           0.390538
#
# IndicatorName                                       Adjusted net enrolment rate, primary, female (%)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                               NaN
# 2005 PPP conversion factor, private consumption...                                               NaN
# Access to electricity (% of population)                                                          NaN
# Access to electricity, rural (% of rural popula...                                               NaN
# Access to electricity, urban (% of urban popula...                                               NaN
# ...                                                                                              ...
# Wage and salaried workers, female (% of females...                                         -0.193241
# Wage and salaried workers, total (% of total em...                                         -0.151878
# Wage and salary workers, male (% of males emplo...                                         -0.235764
# Water productivity, total (constant 2005 US$ GD...                                          1.000000
# Wholesale price index (2010 = 100)                                                          0.695753
#
# IndicatorName                                       ...  \
# IndicatorName                                       ...
# 2005 PPP conversion factor, GDP (LCU per intern...  ...
# 2005 PPP conversion factor, private consumption...  ...
# Access to electricity (% of population)             ...
# Access to electricity, rural (% of rural popula...  ...
# Access to electricity, urban (% of urban popula...  ...
# ...                                                 ...
# Wage and salaried workers, female (% of females...  ...
# Wage and salaried workers, total (% of total em...  ...
# Wage and salary workers, male (% of males emplo...  ...
# Water productivity, total (constant 2005 US$ GD...  ...
# Wholesale price index (2010 = 100)                  ...
#
# IndicatorName                                       Urban population (% of total)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                            NaN
# 2005 PPP conversion factor, private consumption...                            NaN
# Access to electricity (% of population)                                       NaN
# Access to electricity, rural (% of rural popula...                            NaN
# Access to electricity, urban (% of urban popula...                            NaN
# ...                                                                           ...
# Wage and salaried workers, female (% of females...                       0.458991
# Wage and salaried workers, total (% of total em...                       0.034443
# Wage and salary workers, male (% of males emplo...                      -0.548925
# Water productivity, total (constant 2005 US$ GD...                       0.800972
# Wholesale price index (2010 = 100)                                       0.896833
#
# IndicatorName                                       Urban population growth (annual %)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                 NaN
# 2005 PPP conversion factor, private consumption...                                 NaN
# Access to electricity (% of population)                                            NaN
# Access to electricity, rural (% of rural popula...                                 NaN
# Access to electricity, urban (% of urban popula...                                 NaN
# ...                                                                                ...
# Wage and salaried workers, female (% of females...                            0.239842
# Wage and salaried workers, total (% of total em...                            0.530543
# Wage and salary workers, male (% of males emplo...                            0.405166
# Water productivity, total (constant 2005 US$ GD...                            0.650315
# Wholesale price index (2010 = 100)                                           -0.342147
#
# IndicatorName                                       Vulnerable employment, female (% of female employment)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                          -0.997396
# Wage and salaried workers, total (% of total em...                                          -0.658346
# Wage and salary workers, male (% of males emplo...                                           0.307358
# Water productivity, total (constant 2005 US$ GD...                                           0.473160
# Wholesale price index (2010 = 100)                                                           0.377863
#
# IndicatorName                                       Vulnerable employment, male (% of male employment)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                           0.205088
# Wage and salaried workers, total (% of total em...                                          -0.549000
# Wage and salary workers, male (% of males emplo...                                          -0.974185
# Water productivity, total (constant 2005 US$ GD...                                           0.967690
# Wholesale price index (2010 = 100)                                                           0.809573
#
# IndicatorName                                       Vulnerable employment, total (% of total employment)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                          -0.678572
# Wage and salaried workers, total (% of total em...                                          -0.971093
# Wage and salary workers, male (% of males emplo...                                          -0.486531
# Water productivity, total (constant 2005 US$ GD...                                           0.841440
# Wholesale price index (2010 = 100)                                                           0.751642
#
# IndicatorName                                       Wage and salaried workers, female (% of females employed)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                           1.000000
# Wage and salaried workers, total (% of total em...                                           0.683175
# Wage and salary workers, male (% of males emplo...                                          -0.279657
# Water productivity, total (constant 2005 US$ GD...                                          -0.454551
# Wholesale price index (2010 = 100)                                                          -0.339990
#
# IndicatorName                                       Wage and salaried workers, total (% of total employed)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                           0.683175
# Wage and salaried workers, total (% of total em...                                           1.000000
# Wage and salary workers, male (% of males emplo...                                           0.507293
# Water productivity, total (constant 2005 US$ GD...                                          -0.682589
# Wholesale price index (2010 = 100)                                                          -0.631503
#
# IndicatorName                                       Wage and salary workers, male (% of males employed)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                          -0.279657
# Wage and salaried workers, total (% of total em...                                           0.507293
# Wage and salary workers, male (% of males emplo...                                           1.000000
# Water productivity, total (constant 2005 US$ GD...                                          -0.932652
# Wholesale price index (2010 = 100)                                                          -0.714925
#
# IndicatorName                                       Water productivity, total (constant 2005 US$ GDP per cubic meter of total freshwater withdrawal)  \
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                                NaN
# 2005 PPP conversion factor, private consumption...                                                NaN
# Access to electricity (% of population)                                                           NaN
# Access to electricity, rural (% of rural popula...                                                NaN
# Access to electricity, urban (% of urban popula...                                                NaN
# ...                                                                                               ...
# Wage and salaried workers, female (% of females...                                          -0.454551
# Wage and salaried workers, total (% of total em...                                          -0.682589
# Wage and salary workers, male (% of males emplo...                                          -0.932652
# Water productivity, total (constant 2005 US$ GD...                                           1.000000
# Wholesale price index (2010 = 100)                                                           0.949873
#
# IndicatorName                                       Wholesale price index (2010 = 100)
# IndicatorName
# 2005 PPP conversion factor, GDP (LCU per intern...                                 NaN
# 2005 PPP conversion factor, private consumption...                                 NaN
# Access to electricity (% of population)                                            NaN
# Access to electricity, rural (% of rural popula...                                 NaN
# Access to electricity, urban (% of urban popula...                                 NaN
# ...                                                                                ...
# Wage and salaried workers, female (% of females...                           -0.339990
# Wage and salaried workers, total (% of total em...                           -0.631503
# Wage and salary workers, male (% of males emplo...                           -0.714925
# Water productivity, total (constant 2005 US$ GD...                            0.949873
# Wholesale price index (2010 = 100)                                            1.000000
#
# [887 rows x 887 columns]
