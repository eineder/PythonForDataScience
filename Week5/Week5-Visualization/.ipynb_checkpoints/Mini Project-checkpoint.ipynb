# %% [markdown]
# Let's see whether the two indicators
# * Urban population (% of total)
# * Birth rate, crude (per 1,000 people
#
# correlate in general and if they correlate very well in specific countries.

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
data = pd.read_csv('./world-development-indicators/Indicators.csv')

# %%
indicator1 = "Urban population (% of total)"
indicator2 = "Birth rate, crude (per 1,000 people)"
filter1 = data["IndicatorName"] == indicator1
filter2 = data["IndicatorName"] == indicator2
reduced_data = data[filter1 | filter2]
reduced_data = reduced_data.dropna()
pivot = pd.pivot_table(reduced_data, index=['Year', 'CountryName'], columns='IndicatorName', values='Value', aggfunc='mean')
pivot.corr()
# Out:
# IndicatorName                         Birth rate, crude (per 1,000 people)  \
# IndicatorName
# Birth rate, crude (per 1,000 people)                              1.000000
# Urban population (% of total)                                    -0.682624
#
# IndicatorName                         Urban population (% of total)
# IndicatorName
# Birth rate, crude (per 1,000 people)                      -0.682624
# Urban population (% of total)                              1.000000

# %% [markdown]
# Seems like the two indicators have a fairly strong negative correlation over all countries.
#
# Let's find countries where the two indicators correlate even more.

# %%
pivot.head()
# Out:
# IndicatorName        Birth rate, crude (per 1,000 people)  \
# Year CountryName
# 1960 Afghanistan                                   51.276
#      Albania                                       42.240
#      Algeria                                       49.671
#      American Samoa                                   NaN
#      Andorra                                          NaN
#
# IndicatorName        Urban population (% of total)
# Year CountryName
# 1960 Afghanistan                             8.221
#      Albania                                30.705
#      Algeria                                30.510
#      American Samoa                         66.211
#      Andorra                                58.450

# %%
kosovo_filter = data["CountryName"] == "Kosovo"
data[kosovo_filter & filter2]
# Out:
#         CountryName CountryCode                         IndicatorName  \
# 1140554      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1225274      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1310564      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1396148      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1482766      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1570520      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1659323      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1748508      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1839800      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 1945826      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2062666      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2181233      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2304309      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2429121      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2559488      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2694606      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2830019      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 2966922      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3106728      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3255913      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3407798      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3560817      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3715012      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 3870728      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4041472      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4219706      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4398761      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4578976      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4757883      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 4941325      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 5122264      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 5297813      Kosovo         KSV  Birth rate, crude (per 1,000 people)
# 5462688      Kosovo         KSV  Birth rate, crude (per 1,000 people)
#
#           IndicatorCode  Year  Value
# 1140554  SP.DYN.CBRT.IN  1981   31.0
# 1225274  SP.DYN.CBRT.IN  1982   33.4
# 1310564  SP.DYN.CBRT.IN  1983   30.8
# 1396148  SP.DYN.CBRT.IN  1984   33.5
# 1482766  SP.DYN.CBRT.IN  1985   32.1
# 1570520  SP.DYN.CBRT.IN  1986   31.8
# 1659323  SP.DYN.CBRT.IN  1987   32.1
# 1748508  SP.DYN.CBRT.IN  1988   31.4
# 1839800  SP.DYN.CBRT.IN  1989   29.4
# 1945826  SP.DYN.CBRT.IN  1990   29.6
# 2062666  SP.DYN.CBRT.IN  1991   27.5
# 2181233  SP.DYN.CBRT.IN  1992   23.0
# 2304309  SP.DYN.CBRT.IN  1993   22.5
# 2429121  SP.DYN.CBRT.IN  1994   21.8
# 2559488  SP.DYN.CBRT.IN  1995   22.1
# 2694606  SP.DYN.CBRT.IN  1996   22.4
# 2830019  SP.DYN.CBRT.IN  1997   20.6
# 2966922  SP.DYN.CBRT.IN  1998   21.2
# 3106728  SP.DYN.CBRT.IN  1999   22.7
# 3255913  SP.DYN.CBRT.IN  2000   22.8
# 3407798  SP.DYN.CBRT.IN  2001   21.7
# 3560817  SP.DYN.CBRT.IN  2002   20.8
# 3715012  SP.DYN.CBRT.IN  2003   18.3
# 3870728  SP.DYN.CBRT.IN  2004   20.0
# 4041472  SP.DYN.CBRT.IN  2005   20.9
# 4219706  SP.DYN.CBRT.IN  2006   19.1
# 4398761  SP.DYN.CBRT.IN  2007   19.3
# 4578976  SP.DYN.CBRT.IN  2008   19.0
# 4757883  SP.DYN.CBRT.IN  2009   18.8
# 4941325  SP.DYN.CBRT.IN  2010   18.5
# 5122264  SP.DYN.CBRT.IN  2011   18.3
# 5297813  SP.DYN.CBRT.IN  2012   18.0
# 5462688  SP.DYN.CBRT.IN  2013   17.7

# %%
countries = data["CountryName"].unique()
def get_corr(country):
    country_data = reduced_data[reduced_data["CountryName"] == country]
    country_piv = country_data.pivot(index='Year', columns='IndicatorName', values='Value')
    country_piv = country_piv.dropna()
    if country_piv.shape[1] < 2:
        return None
    corr = country_piv.corr()[indicator1][indicator2]
    return corr

# %%
correlation_data = pd.DataFrame(columns=['Country', 'Correlation'])
i = 0
for country in countries:
    correlation = get_corr(country)
    correlation_data.loc[i] = [country] + [correlation]
    #print(country + ": " + str(correlation))
    i = i + 1

highest_correlation = correlation_data.sort_values(by=['Correlation']).head(5)
lowest_correlation = correlation_data.sort_values(by=['Correlation'], ascending=False).head(5)

# %%
highest_correlation
# Out:
#                                            Country  Correlation
# 228                                         Turkey    -0.998797
# 55                                          Bhutan    -0.998288
# 15     Latin America & Caribbean (developing only)    -0.996132
# 89                                         Ecuador    -0.995686
# 14   Latin America & Caribbean (all income levels)    -0.994660

# %%
lowest_correlation
# Out:
#              Country  Correlation
# 36    American Samoa     1.000000
# 71   Channel Islands     0.923783
# 52            Belize     0.909631
# 220       Tajikistan     0.888484
# 144    Liechtenstein     0.875702

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_country(country_data, country):
    fig, axis = plt.subplots()
    # Grid lines, Xticks, Xlabel, Ylabel

    axis.yaxis.grid(True)
    axis.set_title(country,fontsize=10)
    axis.set_xlabel(indicator1,fontsize=10)
    axis.set_ylabel(indicator2,fontsize=10)

    X = country_data[indicator1]
    Y = country_data[indicator2]

    axis.scatter(X, Y)

# %%
for country in highest_correlation["Country"]:
    country_data = reduced_data[reduced_data["CountryName"] == country]
    country_piv = country_data.pivot(index='Year', columns='IndicatorName', values='Value')
    plot_country(country_piv, country)

# %%
for country in lowest_correlation["Country"]:
    country_data = reduced_data[reduced_data["CountryName"] == country]
    country_piv = country_data.pivot(index='Year', columns='IndicatorName', values='Value')
    plot_country(country_piv, country)
